# %% [markdown]
# ## Download Datasets

# %% [markdown]
# ### Download Cityscapes

# %%
# The following code will only execute
# successfully when compression is complete

import kagglehub

# Download latest version
path = kagglehub.dataset_download("alessiogio/cityscapes-correctlabels")

print("Path to dataset files:", path)

# %% [markdown]
# ### Download Tiny Imagenet

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("akash2sharma/tiny-imagenet")

print("Path to dataset files:", path)

# %% [markdown]
# ### Download Fishyscapes Lost and Found

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("alessiogio/fs-l-and-f")

print("Path to dataset files:", path)

# %% [markdown]
# ### Download SMIYC Road Anomaly 21

# %%
# The following code will only execute
# successfully when compression is complete

import kagglehub

# Download latest version
path = kagglehub.dataset_download("alessiogio/smiyc-road-anomaly-21")

print("Path to dataset files:", path)

# %% [markdown]
# ### Download SMIYC Road Obstacles 21

# %%
# The following code will only execute
# successfully when compression is complete

import kagglehub

# Download latest version
path = kagglehub.dataset_download("alessiogio/smiyc-road-obstacles-21")

print("Path to dataset files:", path)

# %% [markdown]
# ### Download SMIYC Road Obstacles validation

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("alessiogio/smiyc-road-obstacles-validation")

print("Path to dataset files:", path)

# %% [markdown]
# ## Git Clone

# %%
# !git clone -b funziona-1 https://github.com/Nome-Provvisorio/AnomalySegmentation.git
# Out:
# Cloning into 'AnomalySegmentation'...
# remote: Enumerating objects: 2260, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 2260 (delta 36), reused 0 (delta 0), pack-reused 2207 (from 3)
# Receiving objects: 100% (2260/2260), 253.05 MiB | 44.86 MiB/s, done.
# Resolving deltas: 100% (480/480), done.

# %%
# %cd "/kaggle/working/AnomalySegmentation"
# %ls
# !git pull origin funziona-1
# Out:
# /kaggle/working/AnomalySegmentation
# eval/  imagenet/  LICENSE  README.md  results.txt  train/  trained_models/
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.15 KiB | 1.15 MiB/s, done.
# From https://github.com/Nome-Provvisorio/AnomalySegmentation
#  * branch            funziona-1 -> FETCH_HEAD
#    2960b60..76b7f83  funziona-1 -> origin/funziona-1
# Updating 2960b60..76b7f83
# Fast-forward
#  eval/evalAnomaly.py | 14 +++++++++-----
#  1 file changed, 9 insertions(+), 5 deletions(-)

# %%
# !pip install visdom
#!pip install torch_xla

#!pip install cityscapesscripts
# !pip install ood_metrics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.0 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408195 sha256=6aa3eb97ceae624ea5ff783af696ff8603643b59822a4e2daf163ef1f6c6ffce
#   Stored in directory: /root/.cache/pip/wheels/42/29/49/5bed207bac4578e4d2c0c5fc0226bfd33a7e2953ea56356855
# Successfully built visdom
# ...

# %% [markdown]
# ## Run Pretraining

# %%
# %cd "/kaggle/working"
# !python3 "AnomalySegmentation/imagenet/main.py" "/kaggle/input/tiny-imagenet/tiny-imagenet-200" --epochs 1
# Out:
# /kaggle/working
# Epoch: [0][0/391][lr:0.1]	Time 15.355 (15.35) / Data 3.726 (3.73)	Loss 0.102 (0.102)	Prec@1 0.00 (0.00)	Prec@5 0.39 (0.39)
# Epoch: [0][10/391][lr:0.1]	Time 2.190 (3.29) / Data 0.000 (0.34)	Loss 0.058 (0.076)	Prec@1 0.00 (0.04)	Prec@5 1.56 (0.50)
# Epoch: [0][20/391][lr:0.1]	Time 2.204 (2.77) / Data 0.000 (0.18)	Loss 0.037 (0.061)	Prec@1 0.39 (0.24)	Prec@5 1.95 (1.06)
# Epoch: [0][30/391][lr:0.1]	Time 2.446 (2.63) / Data 0.000 (0.12)	Loss 0.025 (0.052)	Prec@1 0.00 (0.34)	Prec@5 1.95 (1.37)
# Epoch: [0][40/391][lr:0.1]	Time 2.595 (2.61) / Data 0.000 (0.09)	Loss 0.018 (0.044)	Prec@1 0.78 (0.37)	Prec@5 3.12 (1.51)
# Epoch: [0][50/391][lr:0.1]	Time 2.814 (2.63) / Data 0.000 (0.07)	Loss 0.014 (0.039)	Prec@1 0.00 (0.39)	Prec@5 2.34 (1.59)
# Epoch: [0][60/391][lr:0.1]	Time 2.688 (2.65) / Data 0.000 (0.06)	Loss 0.011 (0.034)	Prec@1 0.39 (0.38)	Prec@5 2.34 (1.63)
# ...

# %% [markdown]
# ## Run training

# %%
# %cd "/kaggle/working/AnomalySegmentation/train"
# !python3 "main.py" --savedir erfnet_training1 --datadir "/kaggle/input/cityscapes-correctlabels/Cityscape" --num-epochs 50 --batch-size 6 
#--decoder --pretrainedEncoder "/kaggle/working/checkpoint_pretrain.pth.tar"
# Out:
# /kaggle/working/AnomalySegmentation/train
# model path is:  erfnet
# Current working directory: /kaggle/working/AnomalySegmentation/train
# Looking for model file at: /kaggle/working/AnomalySegmentation/train/erfnet.py
# ========== ENCODER TRAINING ===========
# Images path: /kaggle/input/cityscapes-correctlabels/Cityscape/leftImg8bit/train
# Labels path: /kaggle/input/cityscapes-correctlabels/Cityscape/gtFine/train
# Number of image files: 2975
# Number of label files: 2975
# Sample image filenames:
# /kaggle/input/cityscapes-correctlabels/Cityscape/leftImg8bit/train/aachen/aachen_000000_000019_leftImg8bit.png
# /kaggle/input/cityscapes-correctlabels/Cityscape/leftImg8bit/train/aachen/aachen_000001_000019_leftImg8bit.png
# /kaggle/input/cityscapes-correctlabels/Cityscape/leftImg8bit/train/aachen/aachen_000002_000019_leftImg8bit.png
# /kaggle/input/cityscapes-correctlabels/Cityscape/leftImg8bit/train/aachen/aachen_000003_000019_leftImg8bit.png
# ...

# %% [markdown]
# ## Convertitore Labels

# %%
# python imports
from __future__ import print_function, absolute_import, division
import os, glob, sys

# cityscapes imports
from cityscapesscripts.helpers.csHelpers import printError
from cityscapesscripts.preparation.json2labelImg import json2labelImg

# The main method
def main():
    # Where to look for Cityscapes

    cityscapesPath = "/kaggle/input/cityscapes/Cityscape"
    # how to search for all ground truth
    searchFine   = os.path.join( cityscapesPath , "gtFine"   , "*" , "*" , "*_gt*_polygons.json" )
    searchCoarse = os.path.join( cityscapesPath , "gtCoarse" , "*" , "*" , "*_gt*_polygons.json" )

    # search files
    filesFine = glob.glob( searchFine )
    filesFine.sort()
    filesCoarse = glob.glob( searchCoarse )
    filesCoarse.sort()

    # concatenate fine and coarse
    files = filesFine + filesCoarse
    # files = filesFine # use this line if fine is enough for now.

    # quit if we did not find anything
    if not files:
        printError( "Did not find any files. Please consult the README." )

    # a bit verbose
    print("Processing {} annotation files".format(len(files)))

    # iterate through files
    progress = 0
    print("Progress: {:>3} %".format( progress * 100 / len(files) ), end=' ')
    for f in files:
        # create the output filename
        dst = f.replace( "_polygons.json" , "_labelTrainIds.png" )

        # do the conversion
        try:
            json2labelImg( f , dst , "trainIds" )
        except:
            print("Failed to convert: {}".format(f))
            raise

        # status
        progress += 1
        print("\rProgress: {:>3} %".format( progress * 100 / len(files) ), end=' ')
        sys.stdout.flush()


# call the main
if __name__ == "__main__":
    main()

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Generates color images for visualization

# %%
# !python3 "/kaggle/working/AnomalySegmentation/eval/eval_cityscapes_color.py" --datadir "/kaggle/input/cityscapes-correctlabels/Cityscape" --subset val --loadDir "/kaggle/working/" --loadWeights "AnomalySegmentation/save/erfnet_training1/model_best.pth"
# Out:
# Loading model: /kaggle/working/erfnet.py
# Loading weights: /kaggle/working/AnomalySegmentation/save/erfnet_training1/model_best.pth
# ...

# %% [markdown]
# ### eval_iou

# %%
# !python3  "/kaggle/working/AnomalySegmentation/eval/eval_iou.py" --datadir "/kaggle/input/cityscapes-correctlabels/Cityscape" --subset val --loadDir "/kaggle/working/" --loadWeights "AnomalySegmentation/trained_models/erfnet_pretrained.pth"
# Out:
# Loading model: /kaggle/working/erfnet.py
# Loading weights: /kaggle/working/AnomalySegmentation/trained_models/erfnet_pretrained.pth
# ...

# %% [markdown]
# ### eval anomaly

# %%
# !python3 "/kaggle/working/AnomalySegmentation/eval/evalAnomaly.py" --input '/kaggle/input/smiyc-road-obstacles-validation/dataset_ObstacleTrack/images' --loadDir "/kaggle/working/" --loadWeights "AnomalySegmentation/trained_models/erfnet_pretrained.pth" --subset val --metric msp-temperature --temperature 0.75
# Out:
# Loading model: /kaggle/working/erfnet.py
# Loading weights: /kaggle/working/AnomalySegmentation/trained_models/erfnet_pretrained.pth
# ...
